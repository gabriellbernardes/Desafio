# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
file_data1 = "../data/data_1__.csv"
file_data2 = "../data/data_2__.csv"
file_data3 = "../data/data_3__.csv"
file_data4 = "../data/data_4__.csv"

# %%
df_data1 = pd.read_csv(file_data1, parse_dates=['data'])
df_data2 = pd.read_csv(file_data2, parse_dates=['data'])
df_data3 = pd.read_csv(file_data3, parse_dates=['data'])
df_data4 = pd.read_csv(file_data4)

# %%
df_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 3 columns):
# index    589 non-null int64
# data     589 non-null datetime64[ns]
# valor    589 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 13.9 KB

# %%
df_data1.head()
# Out:
#    index       data     valor
# 0      0 2016-08-29      9.00
# 1      1 2016-08-30      1.60
# 2      2 2016-08-31  15311.70
# 3      3 2016-09-01  13932.67
# 4      4 2016-09-02  11535.45

# %%
df_tudo = pd.concat([df_data1, df_data2, df_data3])
df_tudo
# Out:
#     index       data      valor
# 0       0 2016-08-29       9.00
# 1       1 2016-08-30       1.60
# 2       2 2016-08-31   15311.70
# 3       3 2016-09-01   13932.67
# 4       4 2016-09-02   11535.45
# 5       5 2016-09-03   25864.32
# 6       6 2016-09-04  161344.35
# 7       7 2016-09-07   46380.31
# 8       8 2016-09-08    7341.94
# 9       9 2016-09-09   20184.57
# 10     10 2016-09-10   28359.77
# 11     11 2016-09-11   91701.65
# 12     12 2016-09-14   14836.67
# 13     13 2016-09-15   12446.20
# 14     14 2016-09-16   12083.45
# 15     15 2016-09-17   31864.65
# 16     16 2016-09-18   94610.57
# 17     17 2016-09-21   16865.56
# 18     18 2016-09-22    9134.95
# 19     19 2016-09-23   17733.30
# 20     20 2016-09-25  115505.50
# 21     21 2016-09-26     580.40
# 22     22 2016-09-28   18110.85
# 23     23 2016-09-29    7492.46
# 24     24 2016-09-30    5652.10
# 25     25 2016-10-01   84379.41
# 26     26 2016-10-02   87796.85
# 27     27 2016-10-05   16684.48
# ...

# %%
#df_data1['day'] = df_data1.data.dt.day
df_tudo['month'] = df_tudo.data.dt.month
df_tudo['year'] = df_tudo.data.dt.year
df_tudo = df_tudo.drop(columns=['data','index'])

# %%
#last_month = df_data1['month'].values == 12

# %%
# df_ultimoMeses = df_data1[last_month]
# df_SemUltimoMeses = df_data1[~last_month]

# %%
df_tudo
# Out:
#         valor  month  year
# 0        9.00      8  2016
# 1        1.60      8  2016
# 2    15311.70      8  2016
# 3    13932.67      9  2016
# 4    11535.45      9  2016
# 5    25864.32      9  2016
# 6   161344.35      9  2016
# 7    46380.31      9  2016
# 8     7341.94      9  2016
# 9    20184.57      9  2016
# 10   28359.77      9  2016
# 11   91701.65      9  2016
# 12   14836.67      9  2016
# 13   12446.20      9  2016
# 14   12083.45      9  2016
# 15   31864.65      9  2016
# 16   94610.57      9  2016
# 17   16865.56      9  2016
# 18    9134.95      9  2016
# 19   17733.30      9  2016
# 20  115505.50      9  2016
# 21     580.40      9  2016
# 22   18110.85      9  2016
# 23    7492.46      9  2016
# 24    5652.10      9  2016
# 25   84379.41     10  2016
# 26   87796.85     10  2016
# 27   16684.48     10  2016
# 28    6360.95     10  2016
# 29   13873.31     10  2016
# ..        ...    ...   ...
# 42    4719.77     10  2018
# 43    5325.13     10  2018
# ...

# %%
df_SemUltimoMeses
# Out:
#          valor  month  year
# 0         9.00      8  2016
# 1         1.60      8  2016
# 2     15311.70      8  2016
# 3     13932.67      9  2016
# 4     11535.45      9  2016
# 5     25864.32      9  2016
# 6    161344.35      9  2016
# 7     46380.31      9  2016
# 8      7341.94      9  2016
# 9     20184.57      9  2016
# 10    28359.77      9  2016
# 11    91701.65      9  2016
# 12    14836.67      9  2016
# 13    12446.20      9  2016
# 14    12083.45      9  2016
# 15    31864.65      9  2016
# 16    94610.57      9  2016
# 17    16865.56      9  2016
# 18     9134.95      9  2016
# 19    17733.30      9  2016
# 20   115505.50      9  2016
# 21      580.40      9  2016
# 22    18110.85      9  2016
# 23     7492.46      9  2016
# 24     5652.10      9  2016
# 25    84379.41     10  2016
# 26    87796.85     10  2016
# 27    16684.48     10  2016
# 28     6360.95     10  2016
# 29    13873.31     10  2016
# ..         ...    ...   ...
# 559   11448.55      9  2018
# ...

# %%
df_agrupado = df_tudo.groupby(['month','year'], as_index=False).sum()

# %%
df_agrupado
# Out:
#     month  year       valor
# 0       1  2015    80715.76
# 1       1  2016   398732.38
# 2       1  2017  1614344.03
# 3       1  2018  1128525.46
# 4       2  2015    72224.63
# 5       2  2016   300369.98
# 6       2  2017   953404.64
# 7       2  2018   865359.64
# 8       3  2015    73179.45
# 9       3  2016   307800.64
# 10      3  2017  1290025.53
# 11      3  2018   916982.79
# 12      4  2015   263512.38
# 13      4  2016   323850.44
# 14      4  2017  1232571.76
# 15      4  2018  1213828.56
# 16      5  2015   325193.14
# 17      5  2016   338480.67
# 18      5  2017  1191163.02
# 19      5  2018  1047290.33
# 20      6  2015   333163.07
# 21      6  2016   332429.23
# 22      6  2017  1112314.26
# 23      6  2018  1138430.96
# 24      7  2014        1.50
# 25      7  2015   402575.47
# 26      7  2016   408854.16
# 27      7  2017  1296257.07
# 28      7  2018  1193697.50
# 29      8  2014    54228.86
# 30      8  2015   331405.31
# 31      8  2016   319178.12
# ...

# %%
X_= pd.DataFrame(df_agrupado[['month', 'year']])
y_pred= pd.DataFrame(df_agrupado['valor'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()

# %%
model.fit(X_, y_pred)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred_month11 = model.predict(np.array([11, 2018]).reshape(1, -1))
pred_month11
# Out:
# array([[1615405.58157206]])

# %%
pred_month12 = model.predict(np.array([12, 2018]).reshape(1, -1))
pred_month12
# Out:
# array([[1666815.65800178]])
